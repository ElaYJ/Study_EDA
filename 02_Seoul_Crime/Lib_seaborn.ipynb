# %% [markdown]
# # Seaborn

# %% [markdown]
# - seaborn은 matplotlib와 함께 실행된다.

# %%
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt 
from matplotlib import rc 
import seaborn as sns 

plt.rcParams["axes.unicode_minus"] = False
rc("font", family="Malgun Gothic")
get_ipython().run_line_magic("matplotlib", "inline")

# %% [markdown]
# ### 🔰 예제1. seaborn 기초

# %%
np.linspace(0, 14, 100)
# Out:
# array([ 0.        ,  0.14141414,  0.28282828,  0.42424242,  0.56565657,
#         0.70707071,  0.84848485,  0.98989899,  1.13131313,  1.27272727,
#         1.41414141,  1.55555556,  1.6969697 ,  1.83838384,  1.97979798,
#         2.12121212,  2.26262626,  2.4040404 ,  2.54545455,  2.68686869,
#         2.82828283,  2.96969697,  3.11111111,  3.25252525,  3.39393939,
#         3.53535354,  3.67676768,  3.81818182,  3.95959596,  4.1010101 ,
#         4.24242424,  4.38383838,  4.52525253,  4.66666667,  4.80808081,
#         4.94949495,  5.09090909,  5.23232323,  5.37373737,  5.51515152,
#         5.65656566,  5.7979798 ,  5.93939394,  6.08080808,  6.22222222,
#         6.36363636,  6.50505051,  6.64646465,  6.78787879,  6.92929293,
#         7.07070707,  7.21212121,  7.35353535,  7.49494949,  7.63636364,
#         7.77777778,  7.91919192,  8.06060606,  8.2020202 ,  8.34343434,
#         8.48484848,  8.62626263,  8.76767677,  8.90909091,  9.05050505,
# ...

# %%
x = np.linspace(0, 14, 100)
y1 = np.sin(x)
y2 = 2 * np.sin(x + 0.5)
y3 = 3 * np.sin(x + 1.0)
y4 = 4 * np.sin(x + 1.5)

plt.figure(figsize=(10, 6))
plt.plot(x, y1, x, y2, x, y3, x, y4) # plot은 실선 그래프이다.
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, y1, x, y2, x, y3, x, y4)
sns.despine(offset=10)
plt.show()

# %% [markdown]
# - sns.set_sytle()
#
# 	- "white", "whitegrid", "ticks", "dark", "darkgrid"

# %%
def drawGraph():
	plt.figure(figsize=(10, 6))
	plt.plot(x, y1, x, y2, x, y3, x, y4)
	plt.show()

# %%
sns.set_style("white")
drawGraph()

# %%
sns.set_style("whitegrid")
drawGraph()

# %%
sns.set_style("ticks")
drawGraph()

# %%
sns.set_style("dark")
drawGraph()

# %%
sns.set_style("darkgrid")
drawGraph()

# %% [markdown]
# ### 🔰 예제2. seaborn tips data
#
# > seaborn에는 실습용 데이터가 몇 개 내장되어 있다. 그 중 하나인 'tips'를 불러온다.
#
# - boxplot</br>
# - swarmplot</br>
# - lmplot</br>

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# #### 🎫 boxplot
#
# - boxplot 그려보기

# %%
tips[tips["total_bill"] > 40]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=tips["total_bill"])
plt.show()

# %% [markdown]
# - boxplot에 컬럼 지정

# %%
tips["day"].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %% [markdown]
# - boxplot의 `hue`, `palette` param
#
# 	- hue : 카테고리 데이터 표현
# 	- palette : Set 1 ~ 3

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='day', y='total_bill', data=tips, hue='smoker', palette="Set3")
plt.show()

# %% [markdown]
# #### 🎫 swarmplot
#
# - color: 0 ~ 1 사이 값,  검은색(0)부터 흰색(1)까지 조절

# %%
plt.figure(figsize=(8, 6))
sns.swarmplot(x="day", y="total_bill", data=tips, color=".5")
plt.show()

# %% [markdown]
# #### 🎫 boxplot with swarmplot

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x="day", y="total_bill", data=tips)
sns.swarmplot(x="day", y="total_bill", data=tips, color="0.25")
plt.show()

# %% [markdown]
# #### 🎫 lmplot
#
# - total_bill과 tip 사이의 관계 파악할 수 있다.
#
# - 그림자 영역이 좁을수록 상관관계가 높다.

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

sns.set_style("darkgrid")
sns.lmplot(x="total_bill", y="tip", data=tips, height=7) # size => height로 변경
plt.show()

# %% [markdown]
# - `hue` param 사용

# %%
sns.lmplot(x="total_bill", y="tip", data=tips, height=7, hue="smoker")
plt.show()

# %% [markdown]
# ### 🔰 예제3. flights data
#
# - heatmap

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %% [markdown]
# - pivot(index, columns, values)
#
# 	- pivot() 함수를 사용해 DataFrame을 재편성한다.

# %%
flights = flights.pivot(index="month", columns="year", values="passengers")
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %% [markdown]
# #### 🎫 heatmap
#
# - heatmap을 이용하면 전체 경향을 알 수 있다.
#
# - 전체 데이터 흐름을 잘 볼 수 있다.

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data=flights, annot=True, fmt="f") # annot=True 데이터 값 표시
plt.show()

# %% [markdown]
# - 다른 colormap 사용

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data=flights, annot=True, fmt="d", cmap="YlGnBu") # fmt="d" 정수형 표현
plt.show()

# %% [markdown]
# - 데이터 해석
#
# 	- 연도가 증가할수록 전체 승객수도 증가
# 	- 연도별로 여름에 승객수가 많았다.
# 	- 연도가 지날수록 겨울철 승객이 증가하려고 하고 있다.

# %% [markdown]
# ### 🔰 예제4. iris data
#
# - iris(붓꽃) 품종 별로 꽃받침(sepal)과 꽃잎(petal)의 길이 데이터
#
# - pairplot

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### 🎫 pairplot
#
# - 모든 경우의 수를 그래프로 보여준다.
#
# - 다수의 컬럼을 비교한다.

# %%
sns.set_style("ticks")
sns.pairplot(iris)
plt.show()

# %% [markdown]
# - `hue` param 사용
#
# - hue="species" : 종별로 색이 구별되어 표현된다.

# %%
iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris, hue="species")
plt.show()

# %% [markdown]
# - 원하는 컬럼만 pairplot

# %%
sns.pairplot(iris,
             x_vars=["sepal_width", "sepal_length"],
             y_vars=["petal_width", "petal_length"], hue="species")
plt.show()

# %% [markdown]
# ### 🔰 예제5. anscombe data
#
# - lmplot

# %%
anscombe = sns.load_dataset("anscombe")
anscombe.tail()
# Out:
#    dataset     x      y
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
anscombe["dataset"].unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
sns.set_style("darkgrid")
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'I'"), ci=None, height=7)
# ci= 신뢰구간(confidence interval) 선택, None은 신뢰구간 영역이 보이지 않게 설정한다.
plt.show()

# %% [markdown]
# - 마커 사이즈 변경

# %%
sns.lmplot(
	x="x", y="y",
	data=anscombe.query("dataset == 'I'"),
	ci=None,
	height=7,
	scatter_kws={"s": 70} # 마커크기 설정
)
plt.show()

# %% [markdown]
# - `order` param

# %%
sns.lmplot(
	x="x", y="y",
	data=anscombe.query("dataset == 'II'"), # 2차식
	order=1, # 차수에 따라 인수 변경
	ci=None,
	height=7,
	scatter_kws={"s": 80}
)
plt.show()

# %%
sns.lmplot(
	x="x", y="y",
	data=anscombe.query("dataset == 'II'"), # 2차식
	order=2, # 차수에 따라 인수 변경
	ci=None,
	height=7,
	scatter_kws={"s": 80}
)
plt.show()

# %% [markdown]
# - `robust` param
#
# - 경향에서 많이 벗어난 값(outlier) 때문에 그리프가 위, 아래로 끌려 갈수 있다.

# %%
sns.lmplot(
	x="x", y="y",
	data=anscombe.query("dataset == 'III'"), # outlier가 존재하는 데이터
	ci=None,
	height=7,
	scatter_kws={"s": 80}
)
plt.show()

# %%
sns.lmplot(
	x="x", y="y",
	data=anscombe.query("dataset == 'III'"), # outlier가 존재하는 데이터
	robust=True, # 경향에서 많이 떨어진 데이터를 무시한다.
	ci=None,
	height=7,
	scatter_kws={"s": 80}
)
plt.show()
