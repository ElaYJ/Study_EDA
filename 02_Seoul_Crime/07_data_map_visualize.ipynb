# %% [markdown]
# # 분석 데이터 지도 시각화

# %%
import pandas as pd
import numpy as np
import folium
import json

crime_anal_norm = pd.read_csv(
    "./result_data/06_crime_in_seoul_final.csv", index_col=0, encoding="utf-8"
)
# 행정 구역에 대한 경계선 좌표가 들어 있는 json 파일
geo_path = "../data/02. skorea_municipalities_geo_simple.json"
geo_str = json.load(open(geo_path, encoding="utf-8"))

# %%
crime_anal_norm.tail()
# Out:
#            살인        강도        강간        절도        폭력      강간검거율       강도검거율  \
# 구별
# 용산구  0.307692  0.230769  0.486434  0.415110  0.595702  85.258964  100.000000
# 은평구  0.461538  0.230769  0.302326  0.464455  0.665667  91.025641   77.777778
# 종로구  0.461538  0.307692  0.461240  0.540842  0.565467  74.369748   75.000000
# 중구   0.230769  0.205128  0.383721  0.599387  0.555972  74.747475   87.500000
# 중랑구  0.615385  0.358974  0.317829  0.471425  0.790605  91.463415  100.000000
#
#           살인검거율      절도검거율      폭력검거율     인구수  CCTV        범죄         검거
# 구별
# 용산구  100.000000  40.228341  84.228188  244444  2096  0.407142  81.943099
# 은평구  100.000000  53.421369  86.636637  491202  2108  0.424951  81.772285
# 종로구   33.333333  39.587629  87.361909  164257  1619  0.467356  61.930524
# 중구   100.000000  42.511628  89.707865  134593  1023  0.394995  78.893394
# 중랑구   87.500000  62.211709  85.714286  412780   916  0.510844  85.377882

# %% [markdown]
# ### 🔰 살인사건
#
# > 살인발생 건수 지도 시각화
#
# - 2016년 서울시에서 어느 정도 살인사건이 있는가?
#
# - 영등포구에서 살인사건이 제일 많이 일어났다

# %%
#StamenTonerLite
tiles="https://tiles.stadiamaps.com/tiles/stamen_toner_lite/{z}/{x}/{y}{r}.png"
attribution='&copy; <a href="https://www.stadiamaps.com/" target="_blank">Stadia Maps</a> &copy; <a href="https://www.stamen.com/" target="_blank">Stamen Design</a> &copy; <a href="https://openmaptiles.org/" target="_blank">OpenMapTiles</a> &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors'

my_map = folium.Map(location=[37.5502, 126.982], tiles=tiles, attr=attribution, zoom_start=11)
# folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles="Stamen Toner") ❌

folium.Choropleth(
    geo_data=geo_str, # 서울시 구 경계선 좌표값이 담긴 데이터
    data=crime_anal_norm["살인"],
    columns=[crime_anal_norm.index, crime_anal_norm["살인"]],
    fill_color="PuRd",
    key_on="feature.id",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="정규화된 살인 발생 건수",
).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a897a09f1758c0b592233358907a4a7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a897a09f1758c0b592233358907a4a7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a897a09f1758c0b592233358907a4a7f = L.map(
#                 &quot;map_a897a09f1758c0b592233358907a4a7f&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8cd2ecaa6893cd2926210488b49be464 = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/stamen_toner_lite/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.stadiamaps.com/\&quot; target=\&quot;_blank\&quot;\u003eStadia Maps\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.stamen.com/\&quot; target=\&quot;_blank\&quot;\u003eStamen Design\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://openmaptiles.org/\&quot; target=\&quot;_blank\&quot;\u003eOpenMapTiles\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8cd2ecaa6893cd2926210488b49be464.addTo(map_a897a09f1758c0b592233358907a4a7f);
#
#
#             var choropleth_57580531b374ef5de617a6a2c8f454c0 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_f9cbba9cd0b6f25374fa5791d6f2e27a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ubd81\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_f9cbba9cd0b6f25374fa5791d6f2e27a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f9cbba9cd0b6f25374fa5791d6f2e27a = L.geoJson(null, {
#                 onEachFeature: geo_json_f9cbba9cd0b6f25374fa5791d6f2e27a_onEachFeature,
#
#                 style: geo_json_f9cbba9cd0b6f25374fa5791d6f2e27a_styler,
#         });
#
#         function geo_json_f9cbba9cd0b6f25374fa5791d6f2e27a_add (data) {
#             geo_json_f9cbba9cd0b6f25374fa5791d6f2e27a
#                 .addData(data);
#         }
#             geo_json_f9cbba9cd0b6f25374fa5791d6f2e27a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026

# %% [markdown]
# ### 🔰 성범죄
#
# - 강남3구 중 2개의 구가 포함되어 있다.

# %%
#StamenTonerLite
tiles='https://tiles.stadiamaps.com/tiles/stamen_toner_lite/{z}/{x}/{y}{r}.png'
attribution='&copy; <a href="https://www.stadiamaps.com/" target="_blank">Stadia Maps</a> &copy; <a href="https://www.stamen.com/" target="_blank">Stamen Design</a> &copy; <a href="https://openmaptiles.org/" target="_blank">OpenMapTiles</a> &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors'

my_map = folium.Map(
	location=[37.5502, 126.982],
	zoom_start=11,
	tiles=tiles,
	attr=attribution
)

folium.Choropleth(
	geo_data=geo_str,
	data=crime_anal_norm["강간"],
	columns=[crime_anal_norm.index, crime_anal_norm["강간"]],
	fill_color="PuRd",
	key_on="feature.id",
    fill_opacity=0.7,
    line_opacity=0.2,
	legend_name="정규화된 강간 발생 건수",
).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d70f20689708b85a789eb3d20295254 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d70f20689708b85a789eb3d20295254&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d70f20689708b85a789eb3d20295254 = L.map(
#                 &quot;map_5d70f20689708b85a789eb3d20295254&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a82eb2370ad1f64042174c4b26ab6d2c = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/stamen_toner_lite/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.stadiamaps.com/\&quot; target=\&quot;_blank\&quot;\u003eStadia Maps\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.stamen.com/\&quot; target=\&quot;_blank\&quot;\u003eStamen Design\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://openmaptiles.org/\&quot; target=\&quot;_blank\&quot;\u003eOpenMapTiles\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a82eb2370ad1f64042174c4b26ab6d2c.addTo(map_5d70f20689708b85a789eb3d20295254);
#
#
#             var choropleth_363683ef5d877ac44dc7ba0fd17da6b3 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_33e7a154cba46584aa4d8ab99f52c941_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uad00\uc545\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_33e7a154cba46584aa4d8ab99f52c941_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_33e7a154cba46584aa4d8ab99f52c941 = L.geoJson(null, {
#                 onEachFeature: geo_json_33e7a154cba46584aa4d8ab99f52c941_onEachFeature,
#
#                 style: geo_json_33e7a154cba46584aa4d8ab99f52c941_styler,
#         });
#
#         function geo_json_33e7a154cba46584aa4d8ab99f52c941_add (data) {
#             geo_json_33e7a154cba46584aa4d8ab99f52c941
#                 .addData(data);
#         }
#             geo_json_33e7a154cba46584aa4d8ab99f52c941_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.1008751

# %% [markdown]
# ### 🔰 5대 범죄
#
# > 5대 범죄 발생 건수 지도 시각화
#
# - 강남구가 역시 포함되어 있다.

# %%
#StamenTonerLite
tiles='https://tiles.stadiamaps.com/tiles/stamen_toner_lite/{z}/{x}/{y}{r}.png'
attribution='&copy; <a href="https://www.stadiamaps.com/" target="_blank">Stadia Maps</a> &copy; <a href="https://www.stamen.com/" target="_blank">Stamen Design</a> &copy; <a href="https://openmaptiles.org/" target="_blank">OpenMapTiles</a> &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors'

my_map = folium.Map(location=[37.5502, 126.982], tiles=tiles, attr=attribution, zoom_start=11)

folium.Choropleth(
    geo_data=geo_str,
    data=crime_anal_norm["범죄"],
    columns=[crime_anal_norm.index, crime_anal_norm["범죄"]],
    fill_color="PuRd",
    key_on="feature.id",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="정규화된 5대 범죄 발생 건수",
).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4b2e6255508c4deb66836cce0aec7bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4b2e6255508c4deb66836cce0aec7bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4b2e6255508c4deb66836cce0aec7bd = L.map(
#                 &quot;map_f4b2e6255508c4deb66836cce0aec7bd&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_978bfc848f773cd9e51829fae608efdd = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/stamen_toner_lite/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.stadiamaps.com/\&quot; target=\&quot;_blank\&quot;\u003eStadia Maps\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.stamen.com/\&quot; target=\&quot;_blank\&quot;\u003eStamen Design\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://openmaptiles.org/\&quot; target=\&quot;_blank\&quot;\u003eOpenMapTiles\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_978bfc848f773cd9e51829fae608efdd.addTo(map_f4b2e6255508c4deb66836cce0aec7bd);
#
#
#             var choropleth_d06983d6a5ca5ec096f2ed121ee77bf3 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_df45751180190766e21ba63691be59e6_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_df45751180190766e21ba63691be59e6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_df45751180190766e21ba63691be59e6 = L.geoJson(null, {
#                 onEachFeature: geo_json_df45751180190766e21ba63691be59e6_onEachFeature,
#
#                 style: geo_json_df45751180190766e21ba63691be59e6_styler,
#         });
#
#         function geo_json_df45751180190766e21ba63691be59e6_add (data) {
#             geo_json_df45751180190766e21ba63691be59e6
#                 .addData(data);
#         }
#             geo_json_df45751180190766e21ba63691be59e6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &q

# %% [markdown]
# ### 🔰 인구 대비 범죄 발생 건수

# %%
# 인구수 대비 범죄발생 비율
tmp_criminal = crime_anal_norm["범죄"] / crime_anal_norm["인구수"]

#StamenTonerLite
tiles='https://tiles.stadiamaps.com/tiles/stamen_toner_lite/{z}/{x}/{y}{r}.png'
attribution='&copy; <a href="https://www.stadiamaps.com/" target="_blank">Stadia Maps</a> &copy; <a href="https://www.stamen.com/" target="_blank">Stamen Design</a> &copy; <a href="https://openmaptiles.org/" target="_blank">OpenMapTiles</a> &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors'

my_map = folium.Map(location=[37.5502, 126.982], tiles=tiles, attr=attribution, zoom_start=11)

folium.Choropleth(
    geo_data=geo_str,
    data=tmp_criminal,
    columns=[crime_anal_norm.index, tmp_criminal],
    fill_color="PuRd",
    key_on="feature.id",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="인구 대비 범죄 발생 건수",
).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_656b5885acc9640a45d196121b092953 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_656b5885acc9640a45d196121b092953&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_656b5885acc9640a45d196121b092953 = L.map(
#                 &quot;map_656b5885acc9640a45d196121b092953&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c85c10863133e4bb444431a3631068e3 = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/stamen_toner_lite/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.stadiamaps.com/\&quot; target=\&quot;_blank\&quot;\u003eStadia Maps\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.stamen.com/\&quot; target=\&quot;_blank\&quot;\u003eStamen Design\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://openmaptiles.org/\&quot; target=\&quot;_blank\&quot;\u003eOpenMapTiles\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c85c10863133e4bb444431a3631068e3.addTo(map_656b5885acc9640a45d196121b092953);
#
#
#             var choropleth_ca95a5c36d7b6b832242aa95cbd3cabe = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_c1959dcdc8e4c6a78dd04512a476b20c_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_c1959dcdc8e4c6a78dd04512a476b20c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c1959dcdc8e4c6a78dd04512a476b20c = L.geoJson(null, {
#                 onEachFeature: geo_json_c1959dcdc8e4c6a78dd04512a476b20c_onEachFeature,
#
#                 style: geo_json_c1959dcdc8e4c6a78dd04512a476b20c_styler,
#         });
#
#         function geo_json_c1959dcdc8e4c6a78dd04512a476b20c_add (data) {
#             geo_json_c1959dcdc8e4c6a78dd04512a476b20c
#                 .addData(data);
#         }
#             geo_json_c1959dcdc8e4c6a78dd04512a476b20c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 3

# %% [markdown]
# </br>
#
# -----

# %% [markdown]
# # 경찰서별 검거 현황과 구별 범죄발생 현황
#
# > 구별 범죄 현황과 경찰서별 검거에 대한 지도 시각화
#
# - 경찰서별 정보를 가지고 범죄발생과 함께 정리

# %%
crime_anal_station = pd.read_csv(
	"./result_data/03_crime_in_seoul_raw_data.csv", encoding="utf-8"
)
crime_anal_station.tail(2)
# Out:
#     구분  강간검거   강간발생  강도검거  강도발생  살인검거  살인발생   절도검거    절도발생    폭력검거    폭력발생  \
# 29  중부  96.0  141.0   3.0   3.0   2.0   2.0  485.0  1204.0  1164.0  1335.0
# 30  혜화  64.0  101.0   6.0   6.0   2.0   2.0  379.0   988.0   842.0   972.0
#
#      구별        lat         lng
# 29   중구  37.563617  126.989652
# 30  종로구  37.571968  126.998957

# %%
crime_anal_station["살인검거"] / crime_anal_station["살인검거"].max()
# Out:
# 0     0.230769
# 1     0.384615
# 2     0.461538
# 3     0.769231
# 4     0.538462
# 5     0.307692
# 6     0.692308
# 7     0.461538
# 8     0.076923
# 9     0.461538
# 10    0.230769
# 11    0.384615
# 12    0.461538
# 13    0.307692
# 14    0.076923
# 15    0.538462
# 16    0.307692
# 17    0.307692
# 18    0.384615
# 19    0.153846
# 20    0.615385
# 21    0.153846
# 22    0.384615
# 23    1.000000
# 24    0.307692
# 25    0.153846
# 26    0.000000
# 27    0.076923
# 28    0.538462
# 29    0.153846
# 30    0.153846
# Name: 살인검거, dtype: float64

# %%
col = ["살인검거", "강도검거", "강간검거", "절도검거", "폭력검거"]
tmp = crime_anal_station[col] / crime_anal_station[col].max() # 정규화 0 ~ 1
crime_anal_station["검거"] = np.mean(tmp, axis=1) # numpy axis=1 행(가로), pandas axis=1 열(세로)
crime_anal_station.head()
# Out:
#    구분   강간검거   강간발생  강도검거  강도발생  살인검거  살인발생    절도검거    절도발생    폭력검거    폭력발생  \
# 0  강남  269.0  339.0  26.0  24.0   3.0   3.0  1129.0  2438.0  2096.0  2336.0
# 1  강동  152.0  160.0  13.0  14.0   5.0   4.0   902.0  1754.0  2201.0  2530.0
# 2  강북  159.0  217.0   4.0   5.0   6.0   7.0   672.0  1222.0  2482.0  2778.0
# 3  강서  239.0  275.0  10.0  10.0  10.0   9.0  1070.0  1952.0  2768.0  3204.0
# 4  관악  264.0  322.0  10.0  12.0   7.0   6.0   937.0  2103.0  2707.0  3235.0
#
#     구별        lat         lng        검거
# 0  강남구  37.509435  127.066958  0.753687
# 1  강동구  37.528511  127.126822  0.578102
# 2  강북구  37.643480  127.011184  0.506577
# 3  강서구  37.551362  126.850280  0.753796
# 4  관악구  37.474395  126.951349  0.695650

# %% [markdown]
# ### 🔰 경찰서 위치를 마커로 지도에 표시

# %%
my_map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

# for idx, rows in crime_anal_station.iterrows():
#     folium.Marker(
#         location=[rows["lat"], rows["lng"]]
#     ).add_to(my_map)

for idx, rows in crime_anal_station.iterrows():
    folium.Marker([rows["lat"], rows["lng"]]).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb4a12520d9d499304c79a7a02bb0a42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb4a12520d9d499304c79a7a02bb0a42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb4a12520d9d499304c79a7a02bb0a42 = L.map(
#                 &quot;map_bb4a12520d9d499304c79a7a02bb0a42&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15238c1c5f9434ad20338efa94fb18f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_15238c1c5f9434ad20338efa94fb18f4.addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_6c9cfc8dd89ae191c017a68027bb5b39 = L.marker(
#                 [37.5094352, 127.0669578],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_8e67442366d8e9c7081eb59d31ef414a = L.marker(
#                 [37.528511, 127.1268224],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_422c8c689986bb5e603533b48458134d = L.marker(
#                 [37.6434801, 127.0111839],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_69dd33cafbdf789772be5bd868516709 = L.marker(
#                 [37.5513622, 126.8502799],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_7dc3e6d5311a0c1a75cc84f525359010 = L.marker(
#                 [37.4743945, 126.9513489],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_08944549cfec85ca12ad67cbb54d3226 = L.marker(
#                 [37.5467284, 127.0857543],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_055587ca3dc9685e8955e21e795d387f = L.marker(
#                 [37.5074418, 126.8902237],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_6edc3e1f5f0f1ef5b47c9bc5bc87709e = L.marker(
#                 [37.4568129, 126.8968061],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_1c53cdb8ef3f1d6c1826c0e6767e161a = L.marker(
#                 [37.5547584, 126.9734981],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_e90851e4c316aae70fb3cb3bb1189c52 = L.marker(
#                 [37.6421389, 127.0710473],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_4514611e288391c3df976f6eab11ed3b = L.marker(
#                 [37.6533589, 127.052682],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_fbc9d2dfacaae79c04bf8e576cdfab42 = L.marker(
#                 [37.5819561, 127.054846],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_9517a3e5dccbc2aeef2c19f90a53ec0b = L.marker(
#                 [37.4988794, 126.9516345],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_c6612772e0460502b59aab030332b793 = L.marker(
#                 [37.550814, 126.954028],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_d0585c641f2077f38e2f2cdaa02cf7a7 = L.marker(
#                 [37.4945959, 126.9831279],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_fd851a0036f45f6d7125b8267df05e5e = L.marker(
#                 [37.5647439, 126.9667705],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_9e7f95e932443063ed9a75f536ffc341 = L.marker(
#                 [37.6020914, 126.9213528],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_a2b35263b50f4ad154b0e40fc1a83862 = L.marker(
#                 [37.4956054, 127.0052504],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_d9f3da2a476ead5c730e61d8686be346 = L.marker(
#                 [37.5617303, 127.0364217],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_8ecc4f9b0737494f211fdcd234e5109f = L.marker(
#                 [37.6056991, 127.0175664],
#                 {}
#             ).addTo(map_bb4a12520d9d499304c79a7a02bb0a42);
#
#
#             var marker_cd07dbac6f7da86b250fd91b7fd323e7 = L.marker(
#                 [37.5019044, 127.

# %% [markdown]
# ### 🔰 검거율을 원으로 시각화
#
# > 검거에 적절한 값을 곱해서 원의 넓이로 사용
#
# - 검거율이 높을수록 원이 커지게 된다.

# %%
my_map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

for idx, row in crime_anal_station.iterrows():
    folium.CircleMarker(
		[row["lat"], row["lng"]],
		radius=row["검거"] * 50,
		popup=row["구분"] + " : " + "%.2f" % row["검거"], # 강남 : 0.75
		color="#3186cc",
        fill=True,
        fill_color="#3186cc"
	).add_to(my_map)
    
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c1921b1b5637c966204b246774b87dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c1921b1b5637c966204b246774b87dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c1921b1b5637c966204b246774b87dd = L.map(
#                 &quot;map_5c1921b1b5637c966204b246774b87dd&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd6b6f6a2f4f70ffaebe610e8417bf30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cd6b6f6a2f4f70ffaebe610e8417bf30.addTo(map_5c1921b1b5637c966204b246774b87dd);
#
#
#             var circle_marker_9937bf869d8c6e38436d0cbeebfc6e2b = L.circleMarker(
#                 [37.5094352, 127.0669578],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 37.68434470210534, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5c1921b1b5637c966204b246774b87dd);
#
#
#         var popup_0a27e11942d903b08dfe057ab9ef0854 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7874cf85c4c4f6f7bb0a5fda85d0a401 = $(`&lt;div id=&quot;html_7874cf85c4c4f6f7bb0a5fda85d0a401&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남 : 0.75&lt;/div&gt;`)[0];
#                 popup_0a27e11942d903b08dfe057ab9ef0854.setContent(html_7874cf85c4c4f6f7bb0a5fda85d0a401);
#
#
#
#         circle_marker_9937bf869d8c6e38436d0cbeebfc6e2b.bindPopup(popup_0a27e11942d903b08dfe057ab9ef0854)
#         ;
#
#
#
#
#             var circle_marker_a7d115ea9edb3edf159aa104d0bf75cc = L.circleMarker(
#                 [37.528511, 127.1268224],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 28.90511259990911, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5c1921b1b5637c966204b246774b87dd);
#
#
#         var popup_d1735dc2162099ddc42ac2ded7399a74 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5021cd6a67077a5e2e1834f1e0a6090 = $(`&lt;div id=&quot;html_d5021cd6a67077a5e2e1834f1e0a6090&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강동 : 0.58&lt;/div&gt;`)[0];
#                 popup_d1735dc2162099ddc42ac2ded7399a74.setContent(html_d5021cd6a67077a5e2e1834f1e0a6090);
#
#
#
#         circle_marker_a7d115ea9edb3edf159aa104d0bf75cc.bindPopup(popup_d1735dc2162099ddc42ac2ded7399a74)
#         ;
#
#
#
#
#             var circle_marker_c606bcbe483c5834c12800a7a85249c0 = L.circleMarker(
#                 [37.6434801, 127.0111839],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25.328840043583213, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5c1921b1b5637c966204b246774b87dd);
#
#
#         var popup_14eb399d19d9a4b688f6bda7d4651b4b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d85e2df2740457af431bd4598bcbf6f7 = $(`&lt;div id=&quot;html_d85e2df2740457af431bd4598bcbf6f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강북 : 0.51&lt;/div&gt;`)[0];
#                 popup_14eb399d19d9a4b688f6bda7d4651b4b.setContent(html_d85e2df2740457af431bd4598bcbf6f7);
#
#
#
#         circle_marker_c606bcbe483c5834c12800a7a85249c0.bindPopup(popup_14eb399d19d9a4b688f6bda7d4651b4b)
#         ;
#
#
#
#
#             var circle_marker_547e8a6fdc019f1be0c444c853ee05a3 = L.circleMarker(
#                 [37.5513622, 126.8502799],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quo

# %%
my_map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

for idx, row in crime_anal_station.iterrows():
    folium.Marker([row["lat"], row["lng"]]).add_to(my_map)    
    folium.CircleMarker(
		[row["lat"], row["lng"]],
		radius=row["검거"] * 50,
		popup=row["구분"] + " : " + "%.2f" % row["검거"], # 강남 : 0.75
		color="purple",#"#3186cc",
        fill=True,
        fill_color="purple"#"#3186cc"
	).add_to(my_map)
    
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_433bfc49263f9c6a5f57f09712c01da7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_433bfc49263f9c6a5f57f09712c01da7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_433bfc49263f9c6a5f57f09712c01da7 = L.map(
#                 &quot;map_433bfc49263f9c6a5f57f09712c01da7&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_351d7f5e7ade2e048a282030f4748317 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_351d7f5e7ade2e048a282030f4748317.addTo(map_433bfc49263f9c6a5f57f09712c01da7);
#
#
#             var marker_3c093d8eb24bc0de47c06308bda2097e = L.marker(
#                 [37.5094352, 127.0669578],
#                 {}
#             ).addTo(map_433bfc49263f9c6a5f57f09712c01da7);
#
#
#             var circle_marker_80c6801855d7c2019ab81079fca60da5 = L.circleMarker(
#                 [37.5094352, 127.0669578],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 37.68434470210534, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_433bfc49263f9c6a5f57f09712c01da7);
#
#
#         var popup_4c9ba2327573de96336bb4124392d46c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2e68199c54b9d707c416a3ef5d921e71 = $(`&lt;div id=&quot;html_2e68199c54b9d707c416a3ef5d921e71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남 : 0.75&lt;/div&gt;`)[0];
#                 popup_4c9ba2327573de96336bb4124392d46c.setContent(html_2e68199c54b9d707c416a3ef5d921e71);
#
#
#
#         circle_marker_80c6801855d7c2019ab81079fca60da5.bindPopup(popup_4c9ba2327573de96336bb4124392d46c)
#         ;
#
#
#
#
#             var marker_5584510b5270a43ebd5538aa0cc2d569 = L.marker(
#                 [37.528511, 127.1268224],
#                 {}
#             ).addTo(map_433bfc49263f9c6a5f57f09712c01da7);
#
#
#             var circle_marker_52a1cdb9d60a2a5841285482fca0dbcc = L.circleMarker(
#                 [37.528511, 127.1268224],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 28.90511259990911, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_433bfc49263f9c6a5f57f09712c01da7);
#
#
#         var popup_4dd01f5f302baa5449ba1216ae5d7c70 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff0d41ecf94c4c3965a52d6fc96f3077 = $(`&lt;div id=&quot;html_ff0d41ecf94c4c3965a52d6fc96f3077&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강동 : 0.58&lt;/div&gt;`)[0];
#                 popup_4dd01f5f302baa5449ba1216ae5d7c70.setContent(html_ff0d41ecf94c4c3965a52d6fc96f3077);
#
#
#
#         circle_marker_52a1cdb9d60a2a5841285482fca0dbcc.bindPopup(popup_4dd01f5f302baa5449ba1216ae5d7c70)
#         ;
#
#
#
#
#             var marker_cc567a8c597ce37a6e1a8655b88101f6 = L.marker(
#                 [37.6434801, 127.0111839],
#                 {}
#             ).addTo(map_433bfc49263f9c6a5f57f09712c01da7);
#
#
#             var circle_marker_da8a46d58c2e419d6233620318ce08ae = L.circleMarker(
#                 [37.6434801, 127.0111839],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25.328840043583213, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_433bfc49263f9c6a5f57f09712c01da7);
#
#
#         var popup_98af20cab095cfeced2d3f684ae3fb18 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_849e51064268d14712b9c338f214ba18 = $(`&lt;div id=&quot;html_849e51064268d14712b9c338f214ba18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&

# %% [markdown]
# ### 🔰 구별 범죄 현황과 경찰서별 검거율을 함께 표시

# %%
my_map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

folium.Choropleth(
    geo_data=geo_str,
    data=crime_anal_norm["범죄"],
    columns=[crime_anal_norm.index, crime_anal_norm["범죄"]],
    fill_color="PuRd",
    key_on="feature.id",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="5대 범죄 발생 비율"
).add_to(my_map)

for idx, rows in crime_anal_station.iterrows():
    folium.CircleMarker(
        location=[rows["lat"], rows["lng"]],
        radius=rows["검거"] * 50,
        popup=rows["구분"] + " : " + "%.2f" % rows["검거"],
        color="#3186cc",
        fill=True,
        fill_color="#3186cc",
    ).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5085bfaf88e911886732233196204413 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5085bfaf88e911886732233196204413&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5085bfaf88e911886732233196204413 = L.map(
#                 &quot;map_5085bfaf88e911886732233196204413&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f32f0b1fc1e8facf5aacf4a4298ebe35 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f32f0b1fc1e8facf5aacf4a4298ebe35.addTo(map_5085bfaf88e911886732233196204413);
#
#
#             var choropleth_293de489e94807c1c181ae84cb343791 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_52528fdf76a2da58700ee579b090f7e8_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_52528fdf76a2da58700ee579b090f7e8_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_52528fdf76a2da58700ee579b090f7e8 = L.geoJson(null, {
#                 onEachFeature: geo_json_52528fdf76a2da58700ee579b090f7e8_onEachFeature,
#
#                 style: geo_json_52528fdf76a2da58700ee579b090f7e8_styler,
#         });
#
#         function geo_json_52528fdf76a2da58700ee579b090f7e8_add (data) {
#             geo_json_52528fdf76a2da58700ee579b090f7e8
#                 .addData(data);
#         }
#             geo_json_52528fdf76a2da58700ee579b090f7e8_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.49744

# %%
#StamenTonerLite
tiles='https://tiles.stadiamaps.com/tiles/stamen_toner_lite/{z}/{x}/{y}{r}.png'
attribution='&copy; <a href="https://www.stadiamaps.com/" target="_blank">Stadia Maps</a> &copy; <a href="https://www.stamen.com/" target="_blank">Stamen Design</a> &copy; <a href="https://openmaptiles.org/" target="_blank">OpenMapTiles</a> &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors'

my_map = folium.Map(location=[37.5502, 126.982], tiles=tiles, attr=attribution, zoom_start=11)

folium.Choropleth(
    geo_data=geo_str,
    data=crime_anal_norm["범죄"],
    columns=[crime_anal_norm.index, crime_anal_norm["범죄"]],
    fill_color="PuRd",
    key_on="feature.id",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="5대 범죄 발생 비율"
).add_to(my_map)

for idx, row in crime_anal_station.iterrows():
    folium.Marker([row["lat"], row["lng"]]).add_to(my_map) 
    folium.CircleMarker(
        location=[row["lat"], row["lng"]],
        radius=row["검거"] * 50,
        popup=row["구분"] + " : " + "%.2f" % row["검거"],
        color="Green",
        fill=True,
        fill_color="Green"
    ).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5abb79e8400eab4de87c728c228dd72e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5abb79e8400eab4de87c728c228dd72e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5abb79e8400eab4de87c728c228dd72e = L.map(
#                 &quot;map_5abb79e8400eab4de87c728c228dd72e&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_69dfbac92e21d0e3fedb5fd7c810386e = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/stamen_toner_lite/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.stadiamaps.com/\&quot; target=\&quot;_blank\&quot;\u003eStadia Maps\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.stamen.com/\&quot; target=\&quot;_blank\&quot;\u003eStamen Design\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://openmaptiles.org/\&quot; target=\&quot;_blank\&quot;\u003eOpenMapTiles\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_69dfbac92e21d0e3fedb5fd7c810386e.addTo(map_5abb79e8400eab4de87c728c228dd72e);
#
#
#             var choropleth_a5240616d250a65059a8090f36fa6de9 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_41124c71279a2711161b58a340783ae5_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_41124c71279a2711161b58a340783ae5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_41124c71279a2711161b58a340783ae5 = L.geoJson(null, {
#                 onEachFeature: geo_json_41124c71279a2711161b58a340783ae5_onEachFeature,
#
#                 style: geo_json_41124c71279a2711161b58a340783ae5_styler,
#         });
#
#         function geo_json_41124c71279a2711161b58a340783ae5_add (data) {
#             geo_json_41124c71279a2711161b58a340783ae5
#                 .addData(data);
#         }
#             geo_json_41124c71279a2711161b58a340783ae5_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &q

# %%
crime_anal_station.to_csv("./result_data/07_crime_detection_rate.csv", encoding="utf-8")
