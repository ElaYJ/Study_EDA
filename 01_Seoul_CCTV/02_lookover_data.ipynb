# %% [markdown]
# # 1. CCTV 데이터 훑어보기

# %%
import pandas as pd

CCTV_Seoul = pd.read_csv("./result_data/01_CCTV_result.csv")

# %%
CCTV_Seoul.head()
# Out:
#    Unnamed: 0   구별    소계  2013년도 이전  2014년  2015년  2016년
# 0           0  강남구  3238       1292    430    584    932
# 1           1  강동구  1010        379     99    155    377
# 2           2  강북구   831        369    120    138    204
# 3           3  강서구   911        388    258    184     81
# 4           4  관악구  2109        846    260    390    613

# %%
CCTV_Seoul.columns
# Out:
# Index(['Unnamed: 0', '구별', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
del CCTV_Seoul['Unnamed: 0']
CCTV_Seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
CCTV_Seoul.tail()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년
# 20  용산구  2096       1368    218    112    398
# 21  은평구  2108       1138    224    278    468
# 22  종로구  1619        464    314    211    630
# 23   중구  1023        413    190     72    348
# 24  중랑구   916        509    121    177    109

# %% [markdown]
# 👆 총 25개의 자료가 존재하는 것을 알 수 있다.

# %% [markdown]
# #### 🔰 가장 많은 CCTV를 보유한 구

# %%
CCTV_Seoul.sort_values(by='소계', ascending=False).head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년
# 0   강남구  3238       1292    430    584    932
# 18  양천구  2482       1843    142     30    467
# 14  서초구  2297       1406    157    336    398
# 4   관악구  2109        846    260    390    613
# 21  은평구  2108       1138    224    278    468

# %%
CCTV_Seoul.sort_values(by='소계').head()
# Out:
#      구별   소계  2013년도 이전  2014년  2015년  2016년
# 9   도봉구  825        238    159     42    386
# 2   강북구  831        369    120    138    204
# 5   광진구  878        573     78     53    174
# 3   강서구  911        388    258    184     81
# 24  중랑구  916        509    121    177    109

# %% [markdown]
# #### 🔰 "최근증가율" 컬럼 추가
#
# - 이전에 보유한 CCTV 개수 대비 최근 3년(2014~2016)간 CCTV를 가장 많이 설치한 구는?

# %%
CCTV_Seoul["최근증가율"] = (
	(CCTV_Seoul["2014년"] + CCTV_Seoul["2015년"] + CCTV_Seoul["2016년"]) / CCTV_Seoul["2013년도 이전"] * 100
)

CCTV_Seoul.sort_values(by='최근증가율', ascending=False).head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 22  종로구  1619        464    314    211    630  248.922414
# 9   도봉구   825        238    159     42    386  246.638655
# 12  마포구   980        314    118    169    379  212.101911
# 8   노원구  1566        542     57    451    516  188.929889
# 1   강동구  1010        379     99    155    377  166.490765

# %%
CCTV_Seoul.to_csv('./result_data/02_CCTV_result.csv', encoding='utf-8', index=False)

# %% [markdown]
# </br>
#
# -----
#
# </br>

# %% [markdown]
# # 2. 인구 데이터 훑어보기

# %%
popul_seoul = pd.read_excel("./result_data/01_Popul_result.xlsx")
popul_seoul.head()
# Out:
#    Unnamed: 0   구별       인구수      한국인     외국인      고령자
# 0           0   합계  10124579  9857426  267153  1365126
# 1           1  종로구    164257   154770    9487    26182
# 2           2   중구    134593   125709    8884    21384
# 3           3  용산구    244444   229161   15283    36882
# 4           4  성동구    312711   304808    7903    41273

# %%
del popul_seoul['Unnamed: 0']
popul_seoul.head()
# Out:
#     구별       인구수      한국인     외국인      고령자
# 0   합계  10124579  9857426  267153  1365126
# 1  종로구    164257   154770    9487    26182
# 2   중구    134593   125709    8884    21384
# 3  용산구    244444   229161   15283    36882
# 4  성동구    312711   304808    7903    41273

# %%
popul_seoul.tail()
# Out:
#      구별     인구수     한국인    외국인    고령자
# 21  관악구  520929  503297  17632  70046
# 22  서초구  445401  441102   4299  53205
# 23  강남구  561052  556164   4888  65060
# 24  송파구  671173  664496   6677  76582
# 25  강동구  440359  436223   4136  56161

# %% [markdown]
# 👆 CCTV 자료의 개수(25)와 맞춰주기 위해 [0]번 "합계" Row를 삭제한다.

# %% [markdown]
# #### 🔰 첫 행(row[0])의 '합계' 데이터 삭제
#
# - '합계' 데이터는 필요 없으므로 행을 지우는 명령인 drop() 메서드를 사용해 지운다.

# %%
popul_seoul.drop([0], inplace=True) # axis=0은 Default값이므로 명시하지 않음.
popul_seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자
# 1  종로구  164257  154770   9487  26182
# 2   중구  134593  125709   8884  21384
# 3  용산구  244444  229161  15283  36882
# 4  성동구  312711  304808   7903  41273
# 5  광진구  372298  357703  14595  43953

# %% [markdown]
# #### 🔰 unique 조사
#
# - 데이터가 많아지면 unique 조사를 통해 데이터를 눈으로 초반 검증한다.
#
# - unique() : 중복값을 제거하고 고유한 값에 무엇이 있는지 리스트로 반환해 준다.

# %%
popul_seoul["구별"].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
len(popul_seoul["구별"].unique())
# Out:
# 25

# %% [markdown]
# #### 🔰 외국인과 고령자 비율 컬럼 추가
#
# - 데이터 행 25개를 컬럼 연산으로 한번에 연산이 가능하다.

# %%
popul_seoul["외국인비율"] = popul_seoul["외국인"] / popul_seoul["인구수"] * 100
popul_seoul["고령자비율"] = popul_seoul["고령자"] / popul_seoul["인구수"] * 100
popul_seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 1  종로구  164257  154770   9487  26182  5.775705  15.939656
# 2   중구  134593  125709   8884  21384  6.600640  15.887899
# 3  용산구  244444  229161  15283  36882  6.252148  15.088118
# 4  성동구  312711  304808   7903  41273  2.527254  13.198448
# 5  광진구  372298  357703  14595  43953  3.920247  11.805865

# %% [markdown]
# #### 🔰 정렬로 정보 확인

# %% [markdown]
# - 인구수가 가장 많은 구는?

# %%
popul_seoul.sort_values(['인구수'], ascending=False).head()
# Out:
#      구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 24  송파구  671173  664496   6677  76582  0.994825  11.410173
# 16  강서구  608255  601691   6564  76032  1.079153  12.500021
# 23  강남구  561052  556164   4888  65060  0.871220  11.596073
# 11  노원구  558075  554403   3672  74243  0.657976  13.303409
# 21  관악구  520929  503297  17632  70046  3.384722  13.446362

# %% [markdown]
# - 외국인이 많은 구는?

# %%
popul_seoul.sort_values(['외국인'], ascending=False).head()
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 19  영등포구  402024  368550  33474  53981  8.326369  13.427308
# 17   구로구  441559  410742  30817  58794  6.979135  13.315095
# 18   금천구  253491  235154  18337  34170  7.233787  13.479769
# 21   관악구  520929  503297  17632  70046  3.384722  13.446362
# 6   동대문구  366011  350647  15364  55718  4.197688  15.223040

# %% [markdown]
# - 외국인 비율이 높은 구는?

# %%
popul_seoul.sort_values(['외국인비율'], ascending=False).head()
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 19  영등포구  402024  368550  33474  53981  8.326369  13.427308
# 18   금천구  253491  235154  18337  34170  7.233787  13.479769
# 17   구로구  441559  410742  30817  58794  6.979135  13.315095
# 2     중구  134593  125709   8884  21384  6.600640  15.887899
# 3    용산구  244444  229161  15283  36882  6.252148  15.088118

# %% [markdown]
# - 고령자가 많은 구는?

# %%
popul_seoul.sort_values(['고령자'], ascending=False).head()
# Out:
#      구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 24  송파구  671173  664496   6677  76582  0.994825  11.410173
# 16  강서구  608255  601691   6564  76032  1.079153  12.500021
# 12  은평구  491202  486794   4408  74559  0.897390  15.178888
# 11  노원구  558075  554403   3672  74243  0.657976  13.303409
# 21  관악구  520929  503297  17632  70046  3.384722  13.446362

# %% [markdown]
# - 고령자 비율이 높은 구는?

# %%
popul_seoul.sort_values(['고령자비율'], ascending=False).head()
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 9    강북구  328002  324479   3523  56530  1.074079  17.234651
# 1    종로구  164257  154770   9487  26182  5.775705  15.939656
# 2     중구  134593  125709   8884  21384  6.600640  15.887899
# 10   도봉구  346234  344166   2068  53488  0.597284  15.448512
# 6   동대문구  366011  350647  15364  55718  4.197688  15.223040

# %%
popul_seoul.to_excel("./result_data/02_Popul_result.xlsx", index=False)
